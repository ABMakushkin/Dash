# %%
import pandas as pd

# %%
poverty_data = pd.read_csv('../data/PovStatsData.csv')

# %%
poverty_data
# Out:
#               Country Name Country Code  \
# 0      East Asia & Pacific          EAS
# 1      East Asia & Pacific          EAS
# 2      East Asia & Pacific          EAS
# 3      East Asia & Pacific          EAS
# 4      East Asia & Pacific          EAS
# ...                    ...          ...
# 11835             Zimbabwe          ZWE
# 11836             Zimbabwe          ZWE
# 11837             Zimbabwe          ZWE
# 11838             Zimbabwe          ZWE
# 11839             Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      Annualized growth in per capita real survey me...     SI.SPR.PC40.ZG
# 1      Annualized growth in per capita real survey me...     SI.SPR.PT10.ZG
# 2      Annualized growth in per capita real survey me...     SI.SPR.PT60.ZG
# 3      Annualized growth in per capita real survey me...     SI.SPR.PCAP.ZG
# 4      Annualized growth in per capita real survey me...  SI.POV.XPND.MD.ZG
# ...

# %%
filtered_df = poverty_data[(poverty_data['Country Name']=='Zimbabwe') &
                               (poverty_data['Indicator Name']=='Population, total')]

# %%
filtered_df
# Out:
#       Country Name Country Code     Indicator Name Indicator Code       1974  \
# 11803     Zimbabwe          ZWE  Population, total    SP.POP.TOTL  6085074.0
#
#             1975       1976       1977       1978       1979  ...        2011  \
# 11803  6293875.0  6502569.0  6712827.0  6929664.0  7160023.0  ...  12894316.0
#
#              2012        2013        2014        2015        2016        2017  \
# 11803  13115131.0  13350356.0  13586681.0  13814629.0  14030390.0  14236745.0
#
#              2018  2019  Unnamed: 50
# 11803  14439018.0   NaN          NaN
#
# [1 rows x 51 columns]

# %%
population = filtered_df.loc[:, '2010'].values[0]

# %%
population
# Out:
# 12697723.0
